# %%
# Add project root to PYTHONPATH
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

# %% [markdown]
# ### Example 1: Single Stock Analysis
#
# Prompt: How has MRNA's stock performed since their COVID vaccine approval?

# %%
# Example 1: Single Stock Analysis
from AppFiles.script import answer_user_query
import plotly.io as pio

result = answer_user_query("How has Moderna's stock performed since their COVID vaccine approval?")
print(result['text'])
pio.show(result["chart_figure"])
# Out:
# RAW PROMPT ► "How has Moderna's stock performed since their COVID vaccine approval?"
# 2025-05-11 19:32:51 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:32:51 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# RAW TICKERS ► 'MRNA'
# Extracted 1 ticker(s): ['MRNA']
# Extracted Tickers: ['MRNA']
# RAW TICKERS ► 'MRNA'
# Extracted 1 ticker(s): ['MRNA']
# Extracted Tickers: ['MRNA']
# Fetching complete historical data for MRNA
# Fetching complete historical data for MRNA
# 2025-05-11 19:33:02 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:33:02 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:33:12 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:33:12 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ...

# %% [markdown]
# ### Example 2: Comparative Stock Analysis
#
# Prompt: Compare VRTX and REGN stock performance in the rare disease space

# %%
# Example 2: Comparative Stock Analysis
from AppFiles.script import answer_user_query
import plotly.io as pio

result = answer_user_query("Compare VRTX and REGN stock performance in the rare disease space")
print(result['text'])
pio.show(result["chart_figure"])
# Out:
# RAW PROMPT ► 'Compare VRTX and REGN stock performance in the rare disease space'
# 2025-05-11 19:33:15 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:33:15 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# RAW TICKERS ► 'VRTX,REGN'
# Extracted 2 ticker(s): ['VRTX', 'REGN']
# Extracted Tickers: ['VRTX', 'REGN']
# RAW TICKERS ► 'VRTX,REGN'
# Extracted 2 ticker(s): ['VRTX', 'REGN']
# Extracted Tickers: ['VRTX', 'REGN']
# Fetching complete historical data for VRTX
# Fetching complete historical data for VRTX
# Fetching complete historical data for REGN
# Fetching complete historical data for REGN
# 2025-05-11 19:33:35 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:33:35 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:33:47 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ...

# %% [markdown]
# ### Example 3: Technical Analysis
#
# Prompt: What are the technical indicators suggesting for GILD stock?

# %%
# Example 3: Technical Analysis
from AppFiles.script import answer_user_query
import plotly.io as pio

result = answer_user_query("What are the technical indicators suggesting for GILD stock?")
print(result['text'])
pio.show(result["chart_figure"])
# Out:
# RAW PROMPT ► 'What are the technical indicators suggesting for GILD stock?'
# 2025-05-11 19:33:49 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:33:49 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# RAW TICKERS ► 'GILD'
# Extracted 1 ticker(s): ['GILD']
# Extracted Tickers: ['GILD']
# Fetching complete historical data for GILD
# RAW TICKERS ► 'GILD'
# Extracted 1 ticker(s): ['GILD']
# Extracted Tickers: ['GILD']
# Fetching complete historical data for GILD
# 2025-05-11 19:34:05 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:34:05 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:34:19 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:34:19 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# === Generated Chart Script ===
# ...

# %% [markdown]
# ### Example 4: Error Handling (No Ticker)
#
# Prompt: Which biotech companies are leading in oncology treatments?

# %%
# Example 4: Error Handling (No Ticker)
from AppFiles.script import answer_user_query
import plotly.io as pio

result = answer_user_query("Which biotech companies are leading in oncology treatments?")
print(result['text'])
pio.show(result["chart_figure"])
# Out:
# RAW PROMPT ► 'Which biotech companies are leading in oncology treatments?'
# 2025-05-11 19:34:25 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:34:25 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# RAW TICKERS ► ''
# Extracted 0 ticker(s): []
# Extracted Tickers: []
# I couldn't identify any stock tickers in your request. Please mention specific companies or stock symbols.
# RAW TICKERS ► ''
# Extracted 0 ticker(s): []
# Extracted Tickers: []
# I couldn't identify any stock tickers in your request. Please mention specific companies or stock symbols.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 7
#       5 result = answer_user_query("Which biotech companies are leading in oncology treatments?")
#       6 print(result['text'])
# ----> 7 pio.show(result["chart_figure"])
#
# ...

# %% [markdown]
# ### Example 5: FDA Approval Impact Analysis
#
# Prompt: How did the FDA approval for BIIB's Alzheimer's drug affect their stock price?

# %%
# Example 5: FDA Approval Impact Analysis
from AppFiles.script import answer_user_query
import plotly.io as pio

result = answer_user_query("How did the FDA approval for BIIB's Alzheimer's drug affect their stock price?")
print(result['text'])
pio.show(result["chart_figure"])
# Out:
# RAW PROMPT ► "How did the FDA approval for BIIB's Alzheimer's drug affect their stock price?"
# 2025-05-11 19:34:40 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:34:40 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# RAW TICKERS ► 'BIIB'
# Extracted 1 ticker(s): ['BIIB']
# Extracted Tickers: ['BIIB']
# RAW TICKERS ► 'BIIB'
# Extracted 1 ticker(s): ['BIIB']
# Extracted Tickers: ['BIIB']
# Fetching complete historical data for BIIB
# Fetching complete historical data for BIIB
# 2025-05-11 19:35:05 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:35:05 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:35:21 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:35:21 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ...
