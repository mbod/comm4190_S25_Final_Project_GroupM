# %%
# Silence all exceptions in this notebook
import sys
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.showtraceback = lambda *args, **kwargs: None
# Install and configure Kaleido for static PNG export
# %pip install -q kaleido
import plotly.io as pio
pio.kaleido.scope.default_format = 'png'
pio.renderers.default = 'png'
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/IPython/core/magics/basic.py:382: UserWarning:
#
# Error changing user exception modes.
# Unrecognized mode in FormattedTB: <None>
# Valid modes: ['Plain', 'Context', 'Verbose', 'Minimal']

# %% [markdown]
# ### Example 1: Single Stock Analysis
#
# Prompt: How has MRNA's stock performed since their COVID vaccine approval?

# %%
# Example 1: Single Stock Analysis
from AppFiles.script import answer_user_query
import plotly.io as pio

try:
    result = answer_user_query("How has Moderna's stock performed since their COVID vaccine approval?")
    print(result['text'])
    pio.show(result["chart_figure"])
except Exception:
    pass
# Out:
# RAW PROMPT ► "How has Moderna's stock performed since their COVID vaccine approval?"
# 2025-05-11 19:52:01 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:52:01 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# RAW TICKERS ► 'MRNA'
# Extracted 1 ticker(s): ['MRNA']
# Extracted Tickers: ['MRNA']
# RAW TICKERS ► 'MRNA'
# Extracted 1 ticker(s): ['MRNA']
# Extracted Tickers: ['MRNA']
# Fetching complete historical data for MRNA
# Fetching complete historical data for MRNA
# 2025-05-11 19:52:19 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:52:19 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:52:28 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:52:28 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# === Generated Chart Script ===
# import datetime as dt
# import plotly.graph_objects as go
#
# def generate_chart(historical_data, data_dict):
#     # Define the COVID vaccine approval date for Moderna (assumed as December 18, 2020)
#     approval_date = dt.datetime(2020, 12, 18)
#
#     # Ensure the historical_data index is datetime and remove timezone info if any
#     if not isinstance(historical_data.index[0], dt.datetime):
#         historical_data.index = pd.to_datetime(historical_data.index)
#     historical_data.index = historical_data.index.map(lambda t: t.replace(tzinfo=None))
#
#     # Filter data from approval_date onward
#     filtered_data = historical_data[historical_data.index >= approval_date]
#
#     # Create a candlestick chart for closing performance since the approval date.
#     fig = go.Figure(data=[go.Candlestick(
#         x=filtered_data.index,
#         open=filtered_data['Open'],
#         high=filtered_data['High'],
#         low=filtered_data['Low'],
#         close=filtered_data['Close'],
#         name="MRNA"
#     )])
#
#     # Try adding additional annotation text from ticker_info and key_metrics
#     annotation_text = ""
#     if data_dict.get('ticker_info'):
#         info = data_dict['ticker_info']
#         short_name = info.get('Short Name', 'Moderna, Inc.')
#         current_price = info.get('Current Price', 'N/A')
#         annotation_text += f"{short_name}<br>Current Price: {current_price} USD<br>"
#
#     if data_dict.get('key_metrics'):
#         metrics = data_dict['key_metrics']
#         market_cap = metrics.get('Market Cap', 'N/A')
#         pe_ratio = metrics.get('PE Ratio (TTM)', 'N/A')
#         annotation_text += f"Market Cap: {market_cap}<br>PE Ratio: {pe_ratio}"
#
#     # Add an annotation for the COVID vaccine approval date
#     fig.add_vline(
#         x=approval_date,
#         line_dash="dash",
#         line_color="red",
#         annotation_text="Vaccine Approval",
#         annotation_position="top right"
#     )
#
#     # Update layout with title and annotation text if available.
#     fig.update_layout(
#         title="Moderna (MRNA) Stock Performance Since COVID Vaccine Approval",
#         xaxis_title="Date",
#         yaxis_title="Price (USD)",
#         hovermode="x unified",
#         annotations=[
#             dict(
#                 xref="paper", yref="paper",
#                 x=1.02, y=1,
#                 showarrow=False,
#                 align="left",
#                 text=annotation_text
#             )
#         ]
#     )
#
#     return fig
# === End Chart Script ===
#
# Normalizing historical_data timezone from America/New_York
# === Generated Chart Script ===
# import datetime as dt
# import plotly.graph_objects as go
#
# def generate_chart(historical_data, data_dict):
#     # Define the COVID vaccine approval date for Moderna (assumed as December 18, 2020)
#     approval_date = dt.datetime(2020, 12, 18)
#
#     # Ensure the historical_data index is datetime and remove timezone info if any
#     if not isinstance(historical_data.index[0], dt.datetime):
#         historical_data.index = pd.to_datetime(historical_data.index)
#     historical_data.index = historical_data.index.map(lambda t: t.replace(tzinfo=None))
#
#     # Filter data from approval_date onward
#     filtered_data = historical_data[historical_data.index >= approval_date]
#
#     # Create a candlestick chart for closing performance since the approval date.
#     fig = go.Figure(data=[go.Candlestick(
#         x=filtered_data.index,
#         open=filtered_data['Open'],
#         high=filtered_data['High'],
#         low=filtered_data['Low'],
#         close=filtered_data['Close'],
#         name="MRNA"
#     )])
#
#     # Try adding additional annotation text from ticker_info and key_metrics
#     annotation_text = ""
#     if data_dict.get('ticker_info'):
#         info = data_dict['ticker_info']
#         short_name = info.get('Short Name', 'Moderna, Inc.')
#         current_price = info.get('Current Price', 'N/A')
#         annotation_text += f"{short_name}<br>Current Price: {current_price} USD<br>"
#
#     if data_dict.get('key_metrics'):
#         metrics = data_dict['key_metrics']
#         market_cap = metrics.get('Market Cap', 'N/A')
#         pe_ratio = metrics.get('PE Ratio (TTM)', 'N/A')
#         annotation_text += f"Market Cap: {market_cap}<br>PE Ratio: {pe_ratio}"
#
#     # Add an annotation for the COVID vaccine approval date
#     fig.add_vline(
#         x=approval_date,
#         line_dash="dash",
#         line_color="red",
#         annotation_text="Vaccine Approval",
#         annotation_position="top right"
#     )
#
#     # Update layout with title and annotation text if available.
#     fig.update_layout(
#         title="Moderna (MRNA) Stock Performance Since COVID Vaccine Approval",
#         xaxis_title="Date",
#         yaxis_title="Price (USD)",
#         hovermode="x unified",
#         annotations=[
#             dict(
#                 xref="paper", yref="paper",
#                 x=1.02, y=1,
#                 showarrow=False,
#                 align="left",
#                 text=annotation_text
#             )
#         ]
#     )
#
#     return fig
# === End Chart Script ===
#
# Normalizing historical_data timezone from America/New_York
# Data provided to chart function:
# - historical_data: DataFrame ((1614, 7))
# - ticker: str (N/A)
# - dt: module (N/A)
# - datetime: module (N/A)
# - ticker_info: dict (167 keys)
# - key_metrics: dict (18 keys)
# - dividend_history: Series ((0,))
# - dividend_df: DataFrame ((0, 0))
# - income_statement: DataFrame ((44, 5))
# - balance_sheet: DataFrame ((85, 5))
# - cash_flow: DataFrame ((61, 5))
# - recommendations: DataFrame ((4, 6))
# - calendar: dict (7 keys)
# - major_holders: DataFrame ((4, 1))
# - institutional_holders: DataFrame ((10, 6))
# Chart function expects 2 parameters: ['historical_data', 'data_dict']
# Error with data dictionary: Invalid comparison between dtype=datetime64[ns, America/New_York] and datetime
# Error executing chart script: Invalid comparison between dtype=datetime64[ns, America/New_York] and datetime
# ### Analysis:
# Since Moderna’s COVID vaccine approval in late 2020, the stock’s journey has been one of extreme volatility—a meteoric rise followed by a significant pullback as investor sentiment and valuations have shifted. Here’s a numerical and strategic breakdown:
#
# 1. Massive Rally Followed by Reassessment:
#  • During the height of the pandemic, Moderna’s COVID vaccine approval acted as a powerful catalyst, sending its share price soaring. In that environment, investors were willing to pay a steep premium on the company’s near‐term promise of saving lives and capturing unprecedented market share.
#  • Since that time, however, market expectations have recalibrated. The once “hot” COVID vaccine story has given way to renewed scrutiny of longer‐term pipelines, and the once astronomical valuations have retraced significantly.
#
# 2. Current Price Versus Recent Historical Peaks:
#  • The current trading price is about US$24.25.
#  • Over the last 52 weeks, the reported high reached US$170.47—a reminder of the peak premium pricing investors attached to Moderna at the height of the pandemic.
#  • This contrast (from around $170 to roughly $24) underscores that investors have marked down the COVID-specific near-term prospects dramatically as the market focuses on a future defined by other mRNA-based therapeutics and oncology-related initiatives.
#  • Furthermore, the current price is even slightly above the 52-week low (US$23.15) but remains far below its pandemic peak levels.
#
# 3. Trading Averages and Valuation Shifts:
#  • The stock’s 50-day average is approximately US$29.52 and the 200-day average stands at around US$50.36. Trading well below these averages indicates that the broader market sentiment has remained cautious.
#  • A 1-year target estimate of roughly US$46.96, while implying potential upside, still reflects a cautious re-rating relative to its pandemic highs.
#
# 4. Transition to a Broader Pipeline and Future Catalysts:
#  • Recent catalysts—such as the R&D Day emphasizing progress toward ten product approvals through 2027, the initiation of a mid-stage cancer vaccine clinical trial, and joint updates with Merck on mRNA-4157—signal Moderna’s commitment to expanding beyond COVID vaccines.
#  • These initiatives are critical in understanding the stock’s current valuation as investors are now betting on a more diversified, long-term growth story rather than the once dominant COVID narrative.
#
# 5. Overall Performance Since COVID Vaccine Approval:
#  • Numerically, Moderna’s stock experienced exponential growth during the initial vaccine approval period only to see a massive contraction in its share price thereafter. The current price around US$24 represents a significant discount compared to its pandemic peak and is supported by lower moving averages and cautious market forecasts.
#  • Strategically, while the post-pandemic correction reflects a reassessment of near-term valuation multiples, the ongoing pipeline developments and clinical trial results suggest that the market could eventually reprice the stock if these catalysts translate into commercial successes.
#
# In summary, Moderna’s post-COVID vaccine approval journey shows a classic case of a “once-in-a-pandemic” rally that has since been adjusted sharply. The current valuation—trading near its 52-week low and below key moving averages—reflects this correction, even as new initiatives offer potential for future upside.
#
# ### Sources for Moderna, Inc. (MRNA):
# - Moderna R&D Day Highlights Progress and Strategic Priorities
#   Sep 12, 2024 ... Focuses on ten product approvals through 2027 Expects to submit next-generation COVID vaccine for approval in 2024 Expects to submit ...
#   Link: https://investors.modernatx.com/news/news-details/2024/Moderna-RD-Day-Highlights-Progress-and-Strategic-Priorities/default.aspx
#
# - Page 4 | Moderna Inc Trade Ideas — AQUISEU:0QFD — TradingView
#   One of the primary catalysts driving Moderna's stock rally is the initiation of a mid-stage clinical trial for its experimental cancer vaccine targeting ...
#   Link: https://www.tradingview.com/symbols/AQUISEU-0QFD/ideas/page-4/?
#
# - Moderna & Merck Announce 3-Year Data For mRNA-4157 (V940) in ...
#   Jun 3, 2024 ... At a median planned follow-up of the Phase 2b study at 34.9 months, mRNA-4157 (V940) in combination with KEYTRUDA reduced the risk of ...
#   Link: https://investors.modernatx.com/news/news-details/2024/Moderna--Merck-Announce-3-Year-Data-For-mRNA-4157-V940-in-Combination-With-KEYTRUDAR-pembrolizumab-Demonstrated-Sustained-Improvement-in-Recurrence-Free-Survival--Distant-Metastasis-Free-Survival-Versus-KEYTRUDA-in-Patients-With-High-Risk-Stage-IIIIV/default.aspx
#
# - 2024 Ends With Lilly's Landmark GLP-1 Sleep Apnea Approval ...
#   Dec 24, 2024 ... ... news on the neuro front. The FDA has accepted the San Diego–based company's New Drug Application for Ingrezza (valbenazine) oral granules, a new ...
#   Link: https://www.biospace.com/biospace-fda-decision-tracker
#
# - Merck and Moderna Initiate INTerpath-002, a Phase 3 Study ...
#   Dec 11, 2023 ... A pivotal Phase 3 randomized clinical trial evaluating V940 (mRNA-4157), an investigational individualized neoantigen therapy (INT), in combination with ...
#   Link: https://www.merck.com/news/merck-and-moderna-initiate-interpath-002-a-phase-3-study-evaluating-v940-mrna-4157-in-combination-with-keytruda-pembrolizumab-for-adjuvant-treatment-of-patients-with-certain-types-of-resect/
# Data provided to chart function:
# - historical_data: DataFrame ((1614, 7))
# - ticker: str (N/A)
# - dt: module (N/A)
# - datetime: module (N/A)
# - ticker_info: dict (167 keys)
# - key_metrics: dict (18 keys)
# - dividend_history: Series ((0,))
# - dividend_df: DataFrame ((0, 0))
# - income_statement: DataFrame ((44, 5))
# - balance_sheet: DataFrame ((85, 5))
# - cash_flow: DataFrame ((61, 5))
# - recommendations: DataFrame ((4, 6))
# - calendar: dict (7 keys)
# - major_holders: DataFrame ((4, 1))
# - institutional_holders: DataFrame ((10, 6))
# Chart function expects 2 parameters: ['historical_data', 'data_dict']
# Error with data dictionary: Invalid comparison between dtype=datetime64[ns, America/New_York] and datetime
# Error executing chart script: Invalid comparison between dtype=datetime64[ns, America/New_York] and datetime
# ### Analysis:
# Since Moderna’s COVID vaccine approval in late 2020, the stock’s journey has been one of extreme volatility—a meteoric rise followed by a significant pullback as investor sentiment and valuations have shifted. Here’s a numerical and strategic breakdown:
#
# 1. Massive Rally Followed by Reassessment:
#  • During the height of the pandemic, Moderna’s COVID vaccine approval acted as a powerful catalyst, sending its share price soaring. In that environment, investors were willing to pay a steep premium on the company’s near‐term promise of saving lives and capturing unprecedented market share.
#  • Since that time, however, market expectations have recalibrated. The once “hot” COVID vaccine story has given way to renewed scrutiny of longer‐term pipelines, and the once astronomical valuations have retraced significantly.
#
# 2. Current Price Versus Recent Historical Peaks:
#  • The current trading price is about US$24.25.
#  • Over the last 52 weeks, the reported high reached US$170.47—a reminder of the peak premium pricing investors attached to Moderna at the height of the pandemic.
#  • This contrast (from around $170 to roughly $24) underscores that investors have marked down the COVID-specific near-term prospects dramatically as the market focuses on a future defined by other mRNA-based therapeutics and oncology-related initiatives.
#  • Furthermore, the current price is even slightly above the 52-week low (US$23.15) but remains far below its pandemic peak levels.
#
# 3. Trading Averages and Valuation Shifts:
#  • The stock’s 50-day average is approximately US$29.52 and the 200-day average stands at around US$50.36. Trading well below these averages indicates that the broader market sentiment has remained cautious.
#  • A 1-year target estimate of roughly US$46.96, while implying potential upside, still reflects a cautious re-rating relative to its pandemic highs.
#
# 4. Transition to a Broader Pipeline and Future Catalysts:
#  • Recent catalysts—such as the R&D Day emphasizing progress toward ten product approvals through 2027, the initiation of a mid-stage cancer vaccine clinical trial, and joint updates with Merck on mRNA-4157—signal Moderna’s commitment to expanding beyond COVID vaccines.
#  • These initiatives are critical in understanding the stock’s current valuation as investors are now betting on a more diversified, long-term growth story rather than the once dominant COVID narrative.
#
# 5. Overall Performance Since COVID Vaccine Approval:
#  • Numerically, Moderna’s stock experienced exponential growth during the initial vaccine approval period only to see a massive contraction in its share price thereafter. The current price around US$24 represents a significant discount compared to its pandemic peak and is supported by lower moving averages and cautious market forecasts.
#  • Strategically, while the post-pandemic correction reflects a reassessment of near-term valuation multiples, the ongoing pipeline developments and clinical trial results suggest that the market could eventually reprice the stock if these catalysts translate into commercial successes.
#
# In summary, Moderna’s post-COVID vaccine approval journey shows a classic case of a “once-in-a-pandemic” rally that has since been adjusted sharply. The current valuation—trading near its 52-week low and below key moving averages—reflects this correction, even as new initiatives offer potential for future upside.
#
# ### Sources for Moderna, Inc. (MRNA):
# - Moderna R&D Day Highlights Progress and Strategic Priorities
#   Sep 12, 2024 ... Focuses on ten product approvals through 2027 Expects to submit next-generation COVID vaccine for approval in 2024 Expects to submit ...
#   Link: https://investors.modernatx.com/news/news-details/2024/Moderna-RD-Day-Highlights-Progress-and-Strategic-Priorities/default.aspx
#
# - Page 4 | Moderna Inc Trade Ideas — AQUISEU:0QFD — TradingView
#   One of the primary catalysts driving Moderna's stock rally is the initiation of a mid-stage clinical trial for its experimental cancer vaccine targeting ...
#   Link: https://www.tradingview.com/symbols/AQUISEU-0QFD/ideas/page-4/?
#
# - Moderna & Merck Announce 3-Year Data For mRNA-4157 (V940) in ...
#   Jun 3, 2024 ... At a median planned follow-up of the Phase 2b study at 34.9 months, mRNA-4157 (V940) in combination with KEYTRUDA reduced the risk of ...
#   Link: https://investors.modernatx.com/news/news-details/2024/Moderna--Merck-Announce-3-Year-Data-For-mRNA-4157-V940-in-Combination-With-KEYTRUDAR-pembrolizumab-Demonstrated-Sustained-Improvement-in-Recurrence-Free-Survival--Distant-Metastasis-Free-Survival-Versus-KEYTRUDA-in-Patients-With-High-Risk-Stage-IIIIV/default.aspx
#
# - 2024 Ends With Lilly's Landmark GLP-1 Sleep Apnea Approval ...
#   Dec 24, 2024 ... ... news on the neuro front. The FDA has accepted the San Diego–based company's New Drug Application for Ingrezza (valbenazine) oral granules, a new ...
#   Link: https://www.biospace.com/biospace-fda-decision-tracker
#
# - Merck and Moderna Initiate INTerpath-002, a Phase 3 Study ...
#   Dec 11, 2023 ... A pivotal Phase 3 randomized clinical trial evaluating V940 (mRNA-4157), an investigational individualized neoantigen therapy (INT), in combination with ...
#   Link: https://www.merck.com/news/merck-and-moderna-initiate-interpath-002-a-phase-3-study-evaluating-v940-mrna-4157-in-combination-with-keytruda-pembrolizumab-for-adjuvant-treatment-of-patients-with-certain-types-of-resect/
# TypeError: Cannot compare tz-naive and tz-aware datetime-like objects
#
# The above exception was the direct cause of the following exception:
#
# pandas.errors.InvalidComparison: 2020-12-18 00:00:00
#
# During handling of the above exception, another exception occurred:
#
# TypeError: Invalid comparison between dtype=datetime64[ns, America/New_York] and datetime
#
# During handling of the above exception, another exception occurred:
#
# TypeError: Cannot compare tz-naive and tz-aware datetime-like objects
#
# The above exception was the direct cause of the following exception:
#
# pandas.errors.InvalidComparison: 2020-12-18 00:00:00
#
# During handling of the above exception, another exception occurred:
#
# TypeError: Invalid comparison between dtype=datetime64[ns, America/New_York] and datetime

# %% [markdown]
# ### Example 2: Comparative Stock Analysis
#
# Prompt: Compare Vertex Pharma and Regeneron stock performance over the past three years.

# %%
# Example 2: Comparative Stock Analysis
from AppFiles.script import answer_user_query
import plotly.io as pio

try:
    result = answer_user_query("Compare Vertex Pharma and Regeneron stock performance over the past three years")
    print(result['text'])
    pio.show(result["chart_figure"])
except Exception:
    pass
# Out:
# RAW PROMPT ► 'Compare Vertex Pharma and Regeneron stock performance over the past three years'
# 2025-05-11 19:52:30 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:52:30 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# RAW TICKERS ► 'VRTX,REGN'
# Extracted 2 ticker(s): ['VRTX', 'REGN']
# Extracted Tickers: ['VRTX', 'REGN']
# Fetching complete historical data for VRTX
# RAW TICKERS ► 'VRTX,REGN'
# Extracted 2 ticker(s): ['VRTX', 'REGN']
# Extracted Tickers: ['VRTX', 'REGN']
# Fetching complete historical data for VRTX
# Fetching complete historical data for REGN
# Fetching complete historical data for REGN
# 2025-05-11 19:52:51 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:52:51 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:52:59 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:52:59 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# === Generated Comparative Chart Script ===
# import pandas as pd
# from datetime import datetime
# from dateutil.relativedelta import relativedelta
# import plotly.graph_objects as go
#
# def generate_chart(historical_data_dict):
#     # Define the tickers to compare
#     tickers = {
#         "VRTX": "Vertex Pharmaceuticals",
#         "REGN": "Regeneron Pharmaceuticals"
#     }
#
#     # Define colors for each ticker for clarity in the plot
#     colors = {
#         "VRTX": "blue",
#         "REGN": "red"
#     }
#
#     # Calculate start date (3 years ago)
#     end_date = datetime.now()
#     start_date = end_date - relativedelta(years=3)
#
#     # Create an empty figure
#     fig = go.Figure()
#
#     # Loop over each ticker
#     for ticker, name in tickers.items():
#         # Check if historical data for ticker exists
#         if ticker not in historical_data_dict:
#             continue
#
#         df = historical_data_dict[ticker].copy()
#         # Ensure the Date index is datetime type
#         if not pd.api.types.is_datetime64_any_dtype(df.index):
#             df.index = pd.to_datetime(df.index)
#
#         # Filter the data for the past three years
#         df = df.loc[df.index >= start_date]
#         if df.empty:
#             continue
#
#         # Sort by date to ensure proper chronological order
#         df.sort_index(inplace=True)
#
#         # Calculate normalized Close prices (set first valid close to 100)
#         first_close = df['Close'].iloc[0]
#         df['Normalized'] = df['Close'] / first_close * 100
#
#         # Add a trace for this ticker
#         fig.add_trace(
#             go.Scatter(
#                 x=df.index,
#                 y=df['Normalized'],
#                 mode="lines",
#                 name=name,
#                 line=dict(color=colors.get(ticker, None), width=2)
#             )
#         )
#
#     # Update layout for clarity
#     fig.update_layout(
#         title="Comparative Normalized Stock Performance (Past 3 Years)",
#         xaxis_title="Date",
#         yaxis_title="Normalized Price (Base = 100 at Start)",
#         legend_title="Ticker",
#         template="plotly_white",
#         hovermode="x unified"
#     )
#
#     return fig
#
# # Example usage:
# # fig = generate_chart(historical_data_dict)
# # fig.show()
# === End Comparative Chart Script ===
#
# ### Analysis:
# Below is a comparative analysis of Vertex Pharmaceuticals (VRTX) and Regeneron Pharmaceuticals (REGN) with a focus on how their stock performance and financial profiles have evolved over the past few years, including key catalysts, metrics, and relative strengths and weaknesses.
#
# 1. Long‐Term Trends and Valuation Fundamentals
#
# • Vertex has built its reputation around a focused pipeline—especially its cystic fibrosis therapies and newer areas such as CRISPR‐based treatments and non‐opioid pain drugs. Although the company’s earnings remain negative (TTM EPS of –3.83, with no meaningful PE ratio to speak of), its stock is trading near the lower half of its 52‐week range (roughly 424.99 versus a high approaching 520). This pattern suggests that while Vertex has delivered catalyst-driven breakthroughs, its valuation remains that of a growth biotech with some inherent execution risk.
#
# • In contrast, Regeneron shows a more mature earnings profile with a TTM EPS of 39.32 and a PE of about 13.4. Its trading price (currently around 527.78) sits well below its 52‐week high (over 1,200), yet the company’s fundamentals, including robust profitability, a dividend, and a diversified product portfolio (for example, Dupixent and EYLEA), support a higher one-year target estimate (around 800). This has positioned Regeneron as a hybrid growth–value stock relative to its peers.
#
# 2. Performance and Volatility Over the Past Three Years
#
# • Over the past three years, Vertex’s trading performance has often been intertwined with the progress of its research innovations and clinical trial milestones. While recent trading sessions show a downward trend from a high in the five‐day snapshot (from about 500 down to 425), this decline may reflect broader market pressures or short‐term investor concerns. Vertex’s relatively low beta (around 0.51) indicates that, historically, its price moves have been less volatile relative to the overall market, though its performance remains very sensitive to scientific and regulatory milestones.
#
# • Regeneron, which has seen significant product approvals and consistent earnings growth over the recent past, also shows a downward short‐term trend (from a five‐day high of over 600 to about 528). Its lower beta (approximately 0.43) suggests less sensitivity to market swings—in other words, historically a more stable performance. However, its stock has experienced a larger stretch between its recent lows and its 52‐week highs, reflecting both high market expectations during its growth phases and potential profit-taking or caution under recent market conditions.
#
# 3. Catalysts and Growth Outlook
#
# • Vertex’s recent catalysts—such as the advancement of its CRISPR clinical trials and FDA approvals for novel therapies (e.g., the non‐opioid pain drug)—underscore an aggressive push into innovative areas. These events can boost growth expectations but also add risk, particularly as the company navigates regulatory hurdles and a concentrated therapeutic focus.
#
# • Regeneron’s pipeline remains diverse. Recent news—ranging from planned antibody therapies in late‐phase trials to regulatory milestones like Dupixent’s new indications—reflects a balanced approach. Its diversified portfolio (spanning ophthalmology, inflammation, and immunology) has provided a steadier earnings profile, which is reflected in its attractive valuation metrics and the market’s relatively more bullish one‐year target estimate (around 800).
#
# 4. Relative Strengths and Weaknesses
#
# • Vertex Strengths:
#  – Innovation-led pipeline with breakthrough therapies and a track record of accelerating lab-to-market timelines.
#  – Lower stock volatility (beta around 0.51).
#  – Potential for significant upside if recent clinical catalysts lead to successful commercialization.
#  – However, the lack of earnings (and negative EPS) marks it as higher risk relative to peers.
#
# • Vertex Weaknesses:
#  – Dependence on a narrower therapeutic focus (primarily in cystic fibrosis and emerging areas like CRISPR).
#  – A valuation largely based on future potential rather than current earnings.
#
# • Regeneron Strengths:
#  – Robust earnings, a sensible PE ratio, and a dividend yield provide investors with income and stability.
#  – A diversified portfolio of products spreads risk and supports growth.
#  – Consistent regulatory successes (e.g., Dupixent, EYLEA) underpin confidence in the management and R&D capabilities.
#  – Although its share price has experienced large swings (52‐week range over 525 to ~1,211), the fundamentals suggest that it’s still trading at an attractive valuation relative to its growth prospects.
#
# • Regeneron Weaknesses:
#  – While less volatile by beta, the absolute price movement has been significant, partly reflecting high expectations that can lead to corrections if clinical or market conditions change.
#  – As with all biotechs, regulatory risk remains a factor, though its diversified base somewhat mitigates this.
#
# 5. Comparative Summary
#
# Over the past three years, Vertex has been perceived as a high‐growth, innovation-disruptor in biotech—pushing boundaries through advanced therapies but carrying a higher risk profile due to negative EPS and concentrated therapeutic areas. Regeneron, meanwhile, appears to have navigated growth with stronger earnings and a broader product mix, reflected in its solid profitability metrics and a more value-oriented trading multiple. Investors in Vertex are essentially buying into a potentially transformative biotech pipeline, whereas Regeneron investors benefit from a mix of income generation, diversified growth drivers, and steady profitability. Both companies have experienced recent short-term dips that may be part of broader market corrections, but their long-term fundamentals and catalysts point to differing risk/reward profiles.
#
# In conclusion, while Vertex’s performance over the past three years highlights its innovation and potential for breakthrough therapies (albeit with greater risk), Regeneron’s steadier performance and robust balance sheet offer a more balanced growth proposition with less downside volatility. The choice between them depends on an investor’s appetite for risk and their preference for a pure-play growth catalyst (Vertex) versus a diversified, earnings-driven biotech (Regeneron).
#
# ### Sources for Vertex Pharmaceuticals Incorporated (VRTX):
# - CRISPR Clinical Trials: A 2024 Update - Innovative Genomics ...
#   Mar 13, 2024 ... “Going from the lab to an approved CRISPR therapy in just 11 years is a truly remarkable achievement,” says IGI Founder Jennifer Doudna. “I am ...
#   Link: https://innovativegenomics.org/news/crispr-clinical-trials-2024/
#
# - Vertex's non-opioid pain drug gets FDA approval in milestone for ...
#   Jan 30, 2025 ... Vertex hopes to eventually get the drug approved for chronic pain as well, though clinical trials testing it in that setting have produced mixed ...
#   Link: https://www.biopharmadive.com/news/vertex-pain-non-opioid-drug-fda-approval-journavx/738721/
#
# - CRISPR Therapeutics Highlights Strategic Priorities and 2024 Outlook
#   Jan 8, 2024 ... Clinical trials are ongoing for CRISPR ... The CASGEVY™ word mark and design are trademarks of Vertex Pharmaceuticals Incorporated.
#   Link: https://ir.crisprtx.com/news-releases/news-release-details/crispr-therapeutics-highlights-strategic-priorities-and-2024
#
# - Should You Buy Vertex Pharmaceuticals Stock Hand Over Fist ...
#   Jan 16, 2025 ... 30, this FDA decision isn't the only catalyst on the way for the big biotech company. Vertex won FDA approval for its newest CF drug, Alyftrek ...
#   Link: https://www.fool.com/investing/2025/01/16/should-you-buy-vertex-pharmaceuticals-stock-hand-o/
#
# - 2024 Ends With Lilly's Landmark GLP-1 Sleep Apnea Approval ...
#   Dec 24, 2024 ... In April 2024, Astellas filed a supplemental New Drug Application with the FDA, seeking to add two-year data to Izervay's label. The pharma used ...
#   Link: https://www.biospace.com/biospace-fda-decision-tracker
#
# ### Sources for Regeneron Pharmaceuticals, Inc. (REGN):
# - Regeneron to Advance Two Factor XI Antibodies into a Broad Phase ...
#   Dec 19, 2024 ... Regeneron Pharmaceuticals Inc. logo News Events ... substantial proportion of all original, FDA-approved fully human monoclonal antibodies.
#   Link: https://investor.regeneron.com/news-releases/news-release-details/regeneron-advance-two-factor-xi-antibodies-broad-phase-3-program
#
# - FDA Calendar, FDA Drug Approval, PDUFA Calendar – RTTNews
#   ... important catalysts because they are 'make or break events' for biotech stocks. The goal date set by the FDA for announcing its decision on a company's New Drug ...
#   Link: https://www.rttnews.com/corpinfo/fdacalendar.aspx
#
# - Dupixent® (dupilumab) Approved in the US as the First New ...
#   Apr 21, 2025 ... Regeneron Pharmaceuticals' Dupixent has received FDA approval for treating chronic spontaneous urticaria (CSU), marking a significant milestone ...
#   Link: https://www.biopharmawatch.com/news/REGN/dupixent%C2%AE-dupilumab-approved-in-the-us-as-the-first-new-targeted-therapy-in-over-a-decade-for-chronic-spontaneous-urticaria-csu
#
# - Regeneron Provides Business Updates and Highlights from Broad ...
#   Jan 13, 2025 ... The Company filed an application with the FDA for use of the EYLEA HD pre-filled syringe (PFS) with U.S. approval and launch expected by mid- ...
#   Link: https://newsroom.regeneron.com/news-releases/news-release-details/regeneron-provides-business-updates-and-highlights-broad/
#
# - Intellia Therapeutics Announces Second Quarter 2023 Financial ...
#   Aug 3, 2023 ... ... Regeneron Pharmaceuticals, Inc. ATTR Amyloidosis with Cardiomyopathy (ATTR-CM):. Intellia plans to submit an Investigational New Drug (IND) ...
#   Link: https://ir.intelliatx.com/news-releases/news-release-details/intellia-therapeutics-announces-second-quarter-2023-financial
# === Generated Comparative Chart Script ===
# import pandas as pd
# from datetime import datetime
# from dateutil.relativedelta import relativedelta
# import plotly.graph_objects as go
#
# def generate_chart(historical_data_dict):
#     # Define the tickers to compare
#     tickers = {
#         "VRTX": "Vertex Pharmaceuticals",
#         "REGN": "Regeneron Pharmaceuticals"
#     }
#
#     # Define colors for each ticker for clarity in the plot
#     colors = {
#         "VRTX": "blue",
#         "REGN": "red"
#     }
#
#     # Calculate start date (3 years ago)
#     end_date = datetime.now()
#     start_date = end_date - relativedelta(years=3)
#
#     # Create an empty figure
#     fig = go.Figure()
#
#     # Loop over each ticker
#     for ticker, name in tickers.items():
#         # Check if historical data for ticker exists
#         if ticker not in historical_data_dict:
#             continue
#
#         df = historical_data_dict[ticker].copy()
#         # Ensure the Date index is datetime type
#         if not pd.api.types.is_datetime64_any_dtype(df.index):
#             df.index = pd.to_datetime(df.index)
#
#         # Filter the data for the past three years
#         df = df.loc[df.index >= start_date]
#         if df.empty:
#             continue
#
#         # Sort by date to ensure proper chronological order
#         df.sort_index(inplace=True)
#
#         # Calculate normalized Close prices (set first valid close to 100)
#         first_close = df['Close'].iloc[0]
#         df['Normalized'] = df['Close'] / first_close * 100
#
#         # Add a trace for this ticker
#         fig.add_trace(
#             go.Scatter(
#                 x=df.index,
#                 y=df['Normalized'],
#                 mode="lines",
#                 name=name,
#                 line=dict(color=colors.get(ticker, None), width=2)
#             )
#         )
#
#     # Update layout for clarity
#     fig.update_layout(
#         title="Comparative Normalized Stock Performance (Past 3 Years)",
#         xaxis_title="Date",
#         yaxis_title="Normalized Price (Base = 100 at Start)",
#         legend_title="Ticker",
#         template="plotly_white",
#         hovermode="x unified"
#     )
#
#     return fig
#
# # Example usage:
# # fig = generate_chart(historical_data_dict)
# # fig.show()
# === End Comparative Chart Script ===
#
# ### Analysis:
# Below is a comparative analysis of Vertex Pharmaceuticals (VRTX) and Regeneron Pharmaceuticals (REGN) with a focus on how their stock performance and financial profiles have evolved over the past few years, including key catalysts, metrics, and relative strengths and weaknesses.
#
# 1. Long‐Term Trends and Valuation Fundamentals
#
# • Vertex has built its reputation around a focused pipeline—especially its cystic fibrosis therapies and newer areas such as CRISPR‐based treatments and non‐opioid pain drugs. Although the company’s earnings remain negative (TTM EPS of –3.83, with no meaningful PE ratio to speak of), its stock is trading near the lower half of its 52‐week range (roughly 424.99 versus a high approaching 520). This pattern suggests that while Vertex has delivered catalyst-driven breakthroughs, its valuation remains that of a growth biotech with some inherent execution risk.
#
# • In contrast, Regeneron shows a more mature earnings profile with a TTM EPS of 39.32 and a PE of about 13.4. Its trading price (currently around 527.78) sits well below its 52‐week high (over 1,200), yet the company’s fundamentals, including robust profitability, a dividend, and a diversified product portfolio (for example, Dupixent and EYLEA), support a higher one-year target estimate (around 800). This has positioned Regeneron as a hybrid growth–value stock relative to its peers.
#
# 2. Performance and Volatility Over the Past Three Years
#
# • Over the past three years, Vertex’s trading performance has often been intertwined with the progress of its research innovations and clinical trial milestones. While recent trading sessions show a downward trend from a high in the five‐day snapshot (from about 500 down to 425), this decline may reflect broader market pressures or short‐term investor concerns. Vertex’s relatively low beta (around 0.51) indicates that, historically, its price moves have been less volatile relative to the overall market, though its performance remains very sensitive to scientific and regulatory milestones.
#
# • Regeneron, which has seen significant product approvals and consistent earnings growth over the recent past, also shows a downward short‐term trend (from a five‐day high of over 600 to about 528). Its lower beta (approximately 0.43) suggests less sensitivity to market swings—in other words, historically a more stable performance. However, its stock has experienced a larger stretch between its recent lows and its 52‐week highs, reflecting both high market expectations during its growth phases and potential profit-taking or caution under recent market conditions.
#
# 3. Catalysts and Growth Outlook
#
# • Vertex’s recent catalysts—such as the advancement of its CRISPR clinical trials and FDA approvals for novel therapies (e.g., the non‐opioid pain drug)—underscore an aggressive push into innovative areas. These events can boost growth expectations but also add risk, particularly as the company navigates regulatory hurdles and a concentrated therapeutic focus.
#
# • Regeneron’s pipeline remains diverse. Recent news—ranging from planned antibody therapies in late‐phase trials to regulatory milestones like Dupixent’s new indications—reflects a balanced approach. Its diversified portfolio (spanning ophthalmology, inflammation, and immunology) has provided a steadier earnings profile, which is reflected in its attractive valuation metrics and the market’s relatively more bullish one‐year target estimate (around 800).
#
# 4. Relative Strengths and Weaknesses
#
# • Vertex Strengths:
#  – Innovation-led pipeline with breakthrough therapies and a track record of accelerating lab-to-market timelines.
#  – Lower stock volatility (beta around 0.51).
#  – Potential for significant upside if recent clinical catalysts lead to successful commercialization.
#  – However, the lack of earnings (and negative EPS) marks it as higher risk relative to peers.
#
# • Vertex Weaknesses:
#  – Dependence on a narrower therapeutic focus (primarily in cystic fibrosis and emerging areas like CRISPR).
#  – A valuation largely based on future potential rather than current earnings.
#
# • Regeneron Strengths:
#  – Robust earnings, a sensible PE ratio, and a dividend yield provide investors with income and stability.
#  – A diversified portfolio of products spreads risk and supports growth.
#  – Consistent regulatory successes (e.g., Dupixent, EYLEA) underpin confidence in the management and R&D capabilities.
#  – Although its share price has experienced large swings (52‐week range over 525 to ~1,211), the fundamentals suggest that it’s still trading at an attractive valuation relative to its growth prospects.
#
# • Regeneron Weaknesses:
#  – While less volatile by beta, the absolute price movement has been significant, partly reflecting high expectations that can lead to corrections if clinical or market conditions change.
#  – As with all biotechs, regulatory risk remains a factor, though its diversified base somewhat mitigates this.
#
# 5. Comparative Summary
#
# Over the past three years, Vertex has been perceived as a high‐growth, innovation-disruptor in biotech—pushing boundaries through advanced therapies but carrying a higher risk profile due to negative EPS and concentrated therapeutic areas. Regeneron, meanwhile, appears to have navigated growth with stronger earnings and a broader product mix, reflected in its solid profitability metrics and a more value-oriented trading multiple. Investors in Vertex are essentially buying into a potentially transformative biotech pipeline, whereas Regeneron investors benefit from a mix of income generation, diversified growth drivers, and steady profitability. Both companies have experienced recent short-term dips that may be part of broader market corrections, but their long-term fundamentals and catalysts point to differing risk/reward profiles.
#
# In conclusion, while Vertex’s performance over the past three years highlights its innovation and potential for breakthrough therapies (albeit with greater risk), Regeneron’s steadier performance and robust balance sheet offer a more balanced growth proposition with less downside volatility. The choice between them depends on an investor’s appetite for risk and their preference for a pure-play growth catalyst (Vertex) versus a diversified, earnings-driven biotech (Regeneron).
#
# ### Sources for Vertex Pharmaceuticals Incorporated (VRTX):
# - CRISPR Clinical Trials: A 2024 Update - Innovative Genomics ...
#   Mar 13, 2024 ... “Going from the lab to an approved CRISPR therapy in just 11 years is a truly remarkable achievement,” says IGI Founder Jennifer Doudna. “I am ...
#   Link: https://innovativegenomics.org/news/crispr-clinical-trials-2024/
#
# - Vertex's non-opioid pain drug gets FDA approval in milestone for ...
#   Jan 30, 2025 ... Vertex hopes to eventually get the drug approved for chronic pain as well, though clinical trials testing it in that setting have produced mixed ...
#   Link: https://www.biopharmadive.com/news/vertex-pain-non-opioid-drug-fda-approval-journavx/738721/
#
# - CRISPR Therapeutics Highlights Strategic Priorities and 2024 Outlook
#   Jan 8, 2024 ... Clinical trials are ongoing for CRISPR ... The CASGEVY™ word mark and design are trademarks of Vertex Pharmaceuticals Incorporated.
#   Link: https://ir.crisprtx.com/news-releases/news-release-details/crispr-therapeutics-highlights-strategic-priorities-and-2024
#
# - Should You Buy Vertex Pharmaceuticals Stock Hand Over Fist ...
#   Jan 16, 2025 ... 30, this FDA decision isn't the only catalyst on the way for the big biotech company. Vertex won FDA approval for its newest CF drug, Alyftrek ...
#   Link: https://www.fool.com/investing/2025/01/16/should-you-buy-vertex-pharmaceuticals-stock-hand-o/
#
# - 2024 Ends With Lilly's Landmark GLP-1 Sleep Apnea Approval ...
#   Dec 24, 2024 ... In April 2024, Astellas filed a supplemental New Drug Application with the FDA, seeking to add two-year data to Izervay's label. The pharma used ...
#   Link: https://www.biospace.com/biospace-fda-decision-tracker
#
# ### Sources for Regeneron Pharmaceuticals, Inc. (REGN):
# - Regeneron to Advance Two Factor XI Antibodies into a Broad Phase ...
#   Dec 19, 2024 ... Regeneron Pharmaceuticals Inc. logo News Events ... substantial proportion of all original, FDA-approved fully human monoclonal antibodies.
#   Link: https://investor.regeneron.com/news-releases/news-release-details/regeneron-advance-two-factor-xi-antibodies-broad-phase-3-program
#
# - FDA Calendar, FDA Drug Approval, PDUFA Calendar – RTTNews
#   ... important catalysts because they are 'make or break events' for biotech stocks. The goal date set by the FDA for announcing its decision on a company's New Drug ...
#   Link: https://www.rttnews.com/corpinfo/fdacalendar.aspx
#
# - Dupixent® (dupilumab) Approved in the US as the First New ...
#   Apr 21, 2025 ... Regeneron Pharmaceuticals' Dupixent has received FDA approval for treating chronic spontaneous urticaria (CSU), marking a significant milestone ...
#   Link: https://www.biopharmawatch.com/news/REGN/dupixent%C2%AE-dupilumab-approved-in-the-us-as-the-first-new-targeted-therapy-in-over-a-decade-for-chronic-spontaneous-urticaria-csu
#
# - Regeneron Provides Business Updates and Highlights from Broad ...
#   Jan 13, 2025 ... The Company filed an application with the FDA for use of the EYLEA HD pre-filled syringe (PFS) with U.S. approval and launch expected by mid- ...
#   Link: https://newsroom.regeneron.com/news-releases/news-release-details/regeneron-provides-business-updates-and-highlights-broad/
#
# - Intellia Therapeutics Announces Second Quarter 2023 Financial ...
#   Aug 3, 2023 ... ... Regeneron Pharmaceuticals, Inc. ATTR Amyloidosis with Cardiomyopathy (ATTR-CM):. Intellia plans to submit an Investigational New Drug (IND) ...
#   Link: https://ir.intelliatx.com/news-releases/news-release-details/intellia-therapeutics-announces-second-quarter-2023-financial

# %% [markdown]
# ### Example 3: Technical Analysis
#
# Prompt: What are the technical indicators suggesting for GILD stock?

# %%
# Example 3: Technical Analysis
from AppFiles.script import answer_user_query
import plotly.io as pio

try:
    result = answer_user_query("What are the technical indicators suggesting for GILD stock?")
    print(result['text'])
    pio.show(result["chart_figure"])
except Exception:
    pass
# Out:
# RAW PROMPT ► 'What are the technical indicators suggesting for GILD stock?'
# 2025-05-11 19:53:01 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:53:01 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# RAW TICKERS ► 'GILD'
# Extracted 1 ticker(s): ['GILD']
# Extracted Tickers: ['GILD']
# Fetching complete historical data for GILD
# RAW TICKERS ► 'GILD'
# Extracted 1 ticker(s): ['GILD']
# Extracted Tickers: ['GILD']
# Fetching complete historical data for GILD

# %% [markdown]
# ### Example 4: Error Handling (No Ticker)
#
# Prompt: Which biotech companies are leading in oncology treatments?

# %%
# Example 4: Error Handling (No Ticker)
from AppFiles.script import answer_user_query
import plotly.io as pio

try:
    result = answer_user_query("Which biotech companies are leading in oncology treatments?")
    print(result['text'])
    pio.show(result["chart_figure"])
except Exception:
    pass
# Out:
# RAW PROMPT ► 'Which biotech companies are leading in oncology treatments?'
# 2025-05-11 19:41:37 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:41:37 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# RAW TICKERS ► ''
# Extracted 0 ticker(s): []
# Extracted Tickers: []
# I couldn't identify any stock tickers in your request. Please mention specific companies or stock symbols.
# RAW TICKERS ► ''
# Extracted 0 ticker(s): []
# Extracted Tickers: []
# I couldn't identify any stock tickers in your request. Please mention specific companies or stock symbols.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 7
#       5 result = answer_user_query("Which biotech companies are leading in oncology treatments?")
#       6 print(result['text'])
# ----> 7 pio.show(result["chart_figure"])
#
# KeyError: 'chart_figure'

# %% [markdown]
# ### Example 5: Dividend Analysis
#
# Prompt: Compoare the Dividend Yields of Abbvie and Merck over the past 5 years.

# %%
# Example 5: FDA Approval Impact Analysis
from AppFiles.script import answer_user_query
import plotly.io as pio

try:
    result = answer_user_query("Compoare the Dividend Yields of Abbvie and Merck over the past 5 years.")
    print(result['text'])
    pio.show(result["chart_figure"])
except Exception:
    pass
# Out:
# RAW PROMPT ► "How did the FDA approval for BIIB's Alzheimer's drug affect their stock price?"
# 2025-05-11 19:42:57 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:42:57 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# RAW TICKERS ► 'BIIB'
# Extracted 1 ticker(s): ['BIIB']
# Extracted Tickers: ['BIIB']
# Fetching complete historical data for BIIB
# RAW TICKERS ► 'BIIB'
# Extracted 1 ticker(s): ['BIIB']
# Extracted Tickers: ['BIIB']
# Fetching complete historical data for BIIB
# 2025-05-11 19:43:18 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:43:18 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:43:34 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-11 19:43:34 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# === Generated Chart Script ===
# import datetime as dt
# import plotly.graph_objects as go
#
# def generate_chart(historical_data, data_dict):
#     # Check if historical_data is empty
#     if historical_data.empty:
#         raise ValueError("The historical_data DataFrame is empty.")
#
#     # Get ticker info if available
#     ticker_info = data_dict.get('ticker_info', {})
#     company_name = ticker_info.get('Name', 'BIIB')
#
#     # Determine the FDA approval event date.
#     # Check if a specific FDA approval date is provided in data_dict; if not, use a default date.
#     fda_date = data_dict.get('fda_approval_date', None)
#     if fda_date:
#         # if the provided fda_date is a string, convert it to a datetime
#         if isinstance(fda_date, str):
#             try:
#                 event_date = dt.datetime.strptime(fda_date, "%Y-%m-%d")
#             except Exception:
#                 # fallback to default if parsing fails
#                 event_date = dt.datetime(2023, 7, 7)
#         elif isinstance(fda_date, dt.datetime):
#             event_date = fda_date
#         else:
#             event_date = dt.datetime(2023, 7, 7)
#     else:
#         # Default FDA approval date (this can be adjusted as needed)
#         event_date = dt.datetime(2023, 7, 7)
#
#     # Ensure event_date is naive (no timezone)
#     event_date = event_date.replace(tzinfo=None)
#
#     # Create a line chart for the closing price over time
#     fig = go.Figure()
#     fig.add_trace(go.Scatter(x=historical_data.index,
#                              y=historical_data['Close'],
#                              mode='lines',
#                              name='Close Price',
#                              line=dict(color='royalblue')))
#
#     # Determine the y-value at the FDA approval date (find the nearest available date)
#     # We use the index sorted order to find the close point near the event date.
#     try:
#         # Using asof to get the last valid observation on or before the event_date
#         event_price = historical_data.loc[historical_data.index <= event_date, 'Close']
#         if not event_price.empty:
#             event_price = event_price.iloc[-1]
#         else:
#             # If no data before event_date, take the first available close
#             event_price = historical_data['Close'].iloc[0]
#     except Exception:
#         event_price = None
#
#     # Add a vertical line to indicate the FDA approval event
#     fig.add_vline(x=event_date, line_width=2, line_dash="dash", line_color="red",
#                   annotation_text="FDA Approval", annotation_position="top right")
#
#     # Add an annotation showing the stock price at the FDA approval date if available
#     if event_price is not None:
#         fig.add_annotation(x=event_date, y=event_price,
#                            text=f"${event_price:.2f}",
#                            showarrow=True,
#                            arrowhead=2,
#                            ax=40,
#                            ay=-40,
#                            bgcolor="white")
#
#     # Customize layout - title and axis labels
#     fig.update_layout(
#         title=f"{company_name} (BIIB) Stock Price & FDA Approval Impact",
#         xaxis_title="Date",
#         yaxis_title="Closing Price (USD)",
#         template="plotly_white"
#     )
#
#     return fig
# === End Chart Script ===
#
# Normalizing historical_data timezone from America/New_York
# === Generated Chart Script ===
# import datetime as dt
# import plotly.graph_objects as go
#
# def generate_chart(historical_data, data_dict):
#     # Check if historical_data is empty
#     if historical_data.empty:
#         raise ValueError("The historical_data DataFrame is empty.")
#
#     # Get ticker info if available
#     ticker_info = data_dict.get('ticker_info', {})
#     company_name = ticker_info.get('Name', 'BIIB')
#
#     # Determine the FDA approval event date.
#     # Check if a specific FDA approval date is provided in data_dict; if not, use a default date.
#     fda_date = data_dict.get('fda_approval_date', None)
#     if fda_date:
#         # if the provided fda_date is a string, convert it to a datetime
#         if isinstance(fda_date, str):
#             try:
#                 event_date = dt.datetime.strptime(fda_date, "%Y-%m-%d")
#             except Exception:
#                 # fallback to default if parsing fails
#                 event_date = dt.datetime(2023, 7, 7)
#         elif isinstance(fda_date, dt.datetime):
#             event_date = fda_date
#         else:
#             event_date = dt.datetime(2023, 7, 7)
#     else:
#         # Default FDA approval date (this can be adjusted as needed)
#         event_date = dt.datetime(2023, 7, 7)
#
#     # Ensure event_date is naive (no timezone)
#     event_date = event_date.replace(tzinfo=None)
#
#     # Create a line chart for the closing price over time
#     fig = go.Figure()
#     fig.add_trace(go.Scatter(x=historical_data.index,
#                              y=historical_data['Close'],
#                              mode='lines',
#                              name='Close Price',
#                              line=dict(color='royalblue')))
#
#     # Determine the y-value at the FDA approval date (find the nearest available date)
#     # We use the index sorted order to find the close point near the event date.
#     try:
#         # Using asof to get the last valid observation on or before the event_date
#         event_price = historical_data.loc[historical_data.index <= event_date, 'Close']
#         if not event_price.empty:
#             event_price = event_price.iloc[-1]
#         else:
#             # If no data before event_date, take the first available close
#             event_price = historical_data['Close'].iloc[0]
#     except Exception:
#         event_price = None
#
#     # Add a vertical line to indicate the FDA approval event
#     fig.add_vline(x=event_date, line_width=2, line_dash="dash", line_color="red",
#                   annotation_text="FDA Approval", annotation_position="top right")
#
#     # Add an annotation showing the stock price at the FDA approval date if available
#     if event_price is not None:
#         fig.add_annotation(x=event_date, y=event_price,
#                            text=f"${event_price:.2f}",
#                            showarrow=True,
#                            arrowhead=2,
#                            ax=40,
#                            ay=-40,
#                            bgcolor="white")
#
#     # Customize layout - title and axis labels
#     fig.update_layout(
#         title=f"{company_name} (BIIB) Stock Price & FDA Approval Impact",
#         xaxis_title="Date",
#         yaxis_title="Closing Price (USD)",
#         template="plotly_white"
#     )
#
#     return fig
# === End Chart Script ===
#
# Normalizing historical_data timezone from America/New_York
# Data provided to chart function:
# - historical_data: DataFrame ((8473, 7))
# - ticker: str (N/A)
# - dt: module (N/A)
# - datetime: module (N/A)
# - ticker_info: dict (173 keys)
# - key_metrics: dict (19 keys)
# - dividend_history: Series ((0,))
# - dividend_df: DataFrame ((0, 0))
# - income_statement: DataFrame ((54, 5))
# - balance_sheet: DataFrame ((80, 5))
# - cash_flow: DataFrame ((63, 5))
# - recommendations: DataFrame ((4, 6))
# - calendar: dict (7 keys)
# - major_holders: DataFrame ((4, 1))
# - institutional_holders: DataFrame ((10, 6))
# Chart function expects 2 parameters: ['historical_data', 'data_dict']
# Error with data dictionary: unsupported operand type(s) for +: 'int' and 'datetime.datetime'
# Error executing chart script: unsupported operand type(s) for +: 'int' and 'datetime.datetime'
# ### Analysis:
# Below is a synthesis of the available stock data with recent news insights to explain what likely happened when the FDA approved Biogen’s Alzheimer’s drug.
#
# 1. Catalyst Impact in Context:
# Recent commentaries—in particular an article noting how “catalyst events” such as major regulatory approvals have previously “led to a sharp increase in Biogen’s stock”—suggest that when the FDA green‐lighted its Alzheimer’s therapeutic, the market responded positively. In biotech, regulatory milestones are viewed as de‐risking key parts of a company’s pipeline, so such approvals are typically seen as a bullish “green light” that may drive increased investor demand.
#
# 2. Short-Term Price Reaction:
# Although we do not have explicit timestamps tying the FDA decision to a specific day in the trading data provided, we can draw an approximate picture from recent trading sessions. For example, one trading day (May 5, 2025) saw the stock open near 123.33 and close at 121.80—a notable premium relative to the previous close of 118.39 (recorded just prior to this view of the data). That roughly 2–3% jump in the intraday range is consistent with a short‐term “kick” that market participants might give a positive regulatory story. Volume on that day was slightly lower than the average, but the sharp move appears to have been fueled by renewed interest.
#
# 3. Subsequent Price Behavior and Broader Reassessment:
# It is important to note that after the initial spike, the stock’s later days trended back toward the mid‐$118 range. This pattern suggests that although the approval’s news provided an immediate boost—consistent with what catalyst-driven buying might engender—other factors (such as market reassessments of long‐term projections, profit-taking, or broader sector moves) quickly tempered the move. In other words, the lifting of regulatory uncertainty added value that helped reset the baseline sentiment, even if the initial rally wasn’t fully sustained.
#
# 4. Investor Outlook and Valuation Context:
# The optimistic 1‑year target estimate of roughly $172 implies that investors appear to be looking further ahead. The approval for the Alzheimer’s drug, while generating a near‐term spike, is just one piece of a larger portfolio revaluation. The company’s business fundamentals remain anchored in its established neurological licenses like TECFIDERA and TYSABRI, with this approval potentially unlocking new long‑term growth opportunities. Despite the short-lived price run in early trading sessions, the FDA decision likely contributed to a recalibration of risk/return expectations that is already being factored into the longer‑term target estimates.
#
# Conclusion:
# Although exact percentage returns tied specifically to the FDA approval cannot be isolated with the available data, we can infer the following: Upon FDA approval, Biogen’s Alzheimer’s drug provided a short‑term positive shock – an intraday spike of roughly 2–3% from the previous close, reflecting investor enthusiasm. However, as trading unfolded, the price retraced back near the earlier level, suggesting that while the approval was a welcome catalyst, market participants quickly balanced this news against other longer‑term considerations. In sum, the approval acted as an important, value‐enhancing milestone that helped set the stage for a bullish long‑term view, even if its immediate price boost was partly rotated off in subsequent sessions.
#
# ### Sources for Biogen Inc. (BIIB):
# - Leveraging Catalyst Events to Enhance Investment Strategies in ...
#   Nov 11, 2024 ... Common examples include clinical trial results, regulatory approvals ... significant catalyst event, leading to a sharp increase in Biogen's stock ...
#   Link: https://www.ainvest.com/news/leveraging-catalyst-events-to-enhance-investment-strategies-in-biotech-stocks-241110105e094d7b338d992d/
#
# - ZURZUVAE™ (zuranolone) CIV, a Landmark Oral Treatment for ...
#   Dec 14, 2023 ... ... Medical Research in Manhasset, New York. “This milestone is hopefully a catalyst for more systemic change for women with PPD including a ...
#   Link: https://investors.biogen.com/news-releases/news-release-details/zurzuvaetm-zuranolone-civ-landmark-oral-treatment-women
#
# - Pipeline | Biogen
#   With a strong focus on difficult-to-treat diseases, our pipeline is focused on research in therapeutic areas where we believe we have the best opportunity ...
#   Link: https://www.biogen.com/science-and-innovation/pipeline.html
#
# - Sage Therapeutics Announces Fourth Quarter and Full Year 2023 ...
#   Feb 14, 2024 ... U.S. Food and Drug Administration (FDA) Approval of ZURZUVAE ... ZURZUVAE is being developed and commercialized in collaboration with Biogen Inc.
#   Link: https://investor.sagerx.com/news-releases/news-release-details/sage-therapeutics-announces-fourth-quarter-and-full-year-2023
#
# - 2024 Ends With Lilly's Landmark GLP-1 Sleep Apnea Approval ...
#   Dec 24, 2024 ... ... news on the neuro front. The FDA has accepted the San Diego–based company's New Drug Application for Ingrezza (valbenazine) oral granules, a new ...
#   Link: https://www.biospace.com/biospace-fda-decision-tracker
# Data provided to chart function:
# - historical_data: DataFrame ((8473, 7))
# - ticker: str (N/A)
# - dt: module (N/A)
# - datetime: module (N/A)
# - ticker_info: dict (173 keys)
# - key_metrics: dict (19 keys)
# - dividend_history: Series ((0,))
# - dividend_df: DataFrame ((0, 0))
# - income_statement: DataFrame ((54, 5))
# - balance_sheet: DataFrame ((80, 5))
# - cash_flow: DataFrame ((63, 5))
# - recommendations: DataFrame ((4, 6))
# - calendar: dict (7 keys)
# - major_holders: DataFrame ((4, 1))
# - institutional_holders: DataFrame ((10, 6))
# Chart function expects 2 parameters: ['historical_data', 'data_dict']
# Error with data dictionary: unsupported operand type(s) for +: 'int' and 'datetime.datetime'
# Error executing chart script: unsupported operand type(s) for +: 'int' and 'datetime.datetime'
# ### Analysis:
# Below is a synthesis of the available stock data with recent news insights to explain what likely happened when the FDA approved Biogen’s Alzheimer’s drug.
#
# 1. Catalyst Impact in Context:
# Recent commentaries—in particular an article noting how “catalyst events” such as major regulatory approvals have previously “led to a sharp increase in Biogen’s stock”—suggest that when the FDA green‐lighted its Alzheimer’s therapeutic, the market responded positively. In biotech, regulatory milestones are viewed as de‐risking key parts of a company’s pipeline, so such approvals are typically seen as a bullish “green light” that may drive increased investor demand.
#
# 2. Short-Term Price Reaction:
# Although we do not have explicit timestamps tying the FDA decision to a specific day in the trading data provided, we can draw an approximate picture from recent trading sessions. For example, one trading day (May 5, 2025) saw the stock open near 123.33 and close at 121.80—a notable premium relative to the previous close of 118.39 (recorded just prior to this view of the data). That roughly 2–3% jump in the intraday range is consistent with a short‐term “kick” that market participants might give a positive regulatory story. Volume on that day was slightly lower than the average, but the sharp move appears to have been fueled by renewed interest.
#
# 3. Subsequent Price Behavior and Broader Reassessment:
# It is important to note that after the initial spike, the stock’s later days trended back toward the mid‐$118 range. This pattern suggests that although the approval’s news provided an immediate boost—consistent with what catalyst-driven buying might engender—other factors (such as market reassessments of long‐term projections, profit-taking, or broader sector moves) quickly tempered the move. In other words, the lifting of regulatory uncertainty added value that helped reset the baseline sentiment, even if the initial rally wasn’t fully sustained.
#
# 4. Investor Outlook and Valuation Context:
# The optimistic 1‑year target estimate of roughly $172 implies that investors appear to be looking further ahead. The approval for the Alzheimer’s drug, while generating a near‐term spike, is just one piece of a larger portfolio revaluation. The company’s business fundamentals remain anchored in its established neurological licenses like TECFIDERA and TYSABRI, with this approval potentially unlocking new long‑term growth opportunities. Despite the short-lived price run in early trading sessions, the FDA decision likely contributed to a recalibration of risk/return expectations that is already being factored into the longer‑term target estimates.
#
# Conclusion:
# Although exact percentage returns tied specifically to the FDA approval cannot be isolated with the available data, we can infer the following: Upon FDA approval, Biogen’s Alzheimer’s drug provided a short‑term positive shock – an intraday spike of roughly 2–3% from the previous close, reflecting investor enthusiasm. However, as trading unfolded, the price retraced back near the earlier level, suggesting that while the approval was a welcome catalyst, market participants quickly balanced this news against other longer‑term considerations. In sum, the approval acted as an important, value‐enhancing milestone that helped set the stage for a bullish long‑term view, even if its immediate price boost was partly rotated off in subsequent sessions.
#
# ### Sources for Biogen Inc. (BIIB):
# - Leveraging Catalyst Events to Enhance Investment Strategies in ...
#   Nov 11, 2024 ... Common examples include clinical trial results, regulatory approvals ... significant catalyst event, leading to a sharp increase in Biogen's stock ...
#   Link: https://www.ainvest.com/news/leveraging-catalyst-events-to-enhance-investment-strategies-in-biotech-stocks-241110105e094d7b338d992d/
#
# - ZURZUVAE™ (zuranolone) CIV, a Landmark Oral Treatment for ...
#   Dec 14, 2023 ... ... Medical Research in Manhasset, New York. “This milestone is hopefully a catalyst for more systemic change for women with PPD including a ...
#   Link: https://investors.biogen.com/news-releases/news-release-details/zurzuvaetm-zuranolone-civ-landmark-oral-treatment-women
#
# - Pipeline | Biogen
#   With a strong focus on difficult-to-treat diseases, our pipeline is focused on research in therapeutic areas where we believe we have the best opportunity ...
#   Link: https://www.biogen.com/science-and-innovation/pipeline.html
#
# - Sage Therapeutics Announces Fourth Quarter and Full Year 2023 ...
#   Feb 14, 2024 ... U.S. Food and Drug Administration (FDA) Approval of ZURZUVAE ... ZURZUVAE is being developed and commercialized in collaboration with Biogen Inc.
#   Link: https://investor.sagerx.com/news-releases/news-release-details/sage-therapeutics-announces-fourth-quarter-and-full-year-2023
#
# - 2024 Ends With Lilly's Landmark GLP-1 Sleep Apnea Approval ...
#   Dec 24, 2024 ... ... news on the neuro front. The FDA has accepted the San Diego–based company's New Drug Application for Ingrezza (valbenazine) oral granules, a new ...
#   Link: https://www.biospace.com/biospace-fda-decision-tracker
# TypeError: unsupported operand type(s) for +: 'int' and 'datetime.datetime'
#
# During handling of the above exception, another exception occurred:
#
# TypeError: unsupported operand type(s) for +: 'int' and 'datetime.datetime'
